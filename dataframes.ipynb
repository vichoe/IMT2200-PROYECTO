# %%
import pandas as pd

# %% [markdown]
# rutas

# %%
cuarto2023 = "data/Simce 4° básico 2023/Archivos CSV (Planos)/simce4b2023_rbd_público_final.csv"
cuarto2022 = "data/Simce 4° básico 2022/Archivos CSV (Planos)/simce4b2022_rbd_final.csv"
cuarto2018 = 'data/Simce 4° básico 2018/Archivos XLS (XLSX)/simce4b2018_rbd_publica_final.xlsx'
cuarto2017 = "data/Simce 4° Basico 2017/Archivos XLS (XLSX)/simce4b2017_rbd_publica_final.xlsx"
# aca añadir mas:

# %% [markdown]
# ### IMPORTANTE
# Hay que ver manualmente cual es la separacion de cada csv (ej, el del primero es un ";" y el del segundo es un "|", asi que no se puede usar el mismo codigo para todos)
#
# ### FILAS RELEVANTES
# Vayamos dejando las filas de
#
# - nombre
# - vulnerabilidad
# - "añadir otros aqui"

# %%
# filtrado

def filtrar(df):
    df = df.drop(['agno', 'palu_eda_ins_lect4b_rbd'], axis=1)
    return df

# luego ir añadiendo mas :)

# %%
df23 = pd.read_csv(cuarto2023, encoding='ISO-8859-1', sep=';')
df23 = filtrar(df23)
df23.head()
# Out:
#      rbd  dvrbd                    nom_rbd  cod_reg_rbd  \
# 0  11407      3  ESCUELA BASICA LOS OLIVOS           16
# 1  14324      3      COLEGIO WILLIAM JAMES            5
# 2  24403      1      COLEGIO SIMON BOLIVAR           13
# 3   2917      3              ESCUELA RAUCO            7
# 4   4506      3    ESCUELA HÉROES DE CHILE            8
#
#                  nom_reg_rbd  cod_pro_rbd nom_pro_rbd  cod_com_rbd  \
# 0                   DE ÑUBLE          162       ITATA        16206
# 1              DE VALPARAÍSO           51  VALPARAÍSO         5109
# 2  METROPOLITANA DE SANTIAGO          131    SANTIAGO        13112
# 3                  DEL MAULE           73      CURICÓ         7305
# 4                 DEL BIOBÍO           83      BIOBÍO         8313
#
#     nom_com_rbd  cod_deprov_rbd  ... marcadif_mate4b_rbd  \
# 0       RÁNQUIL             161  ...                 2.0
# 1  VIÑA DEL MAR              53  ...                 2.0
# ...

# %%
df22 = pd.read_csv(cuarto2022, encoding='ISO-8859-1', sep='|')
df22 = filtrar(df22)
df22.head()
# Out:
#   grado    rbd  dvrbd                                       nom_rbd  \
# 0    4b   7423      3  ESCUELA RURAL ALEJANDRO VASQUEZ BALDEVELLANO
# 1    4b   5834      3                         ESC. BASICA ALTO MECO
# 2    4b   4506      3                       ESCUELA HÉROES DE CHILE
# 3    4b  11407      3                     ESCUELA BASICA LOS OLIVOS
# 4    4b  14324      3                         COLEGIO WILLIAM JAMES
#
#    cod_reg_rbd      nom_reg_rbd  cod_pro_rbd nom_pro_rbd  cod_com_rbd  \
# 0           10     DE LOS LAGOS          103      OSORNO        10307
# 1            9  DE LA ARAUCANÍA           91      CAUTÍN         9108
# 2            8       DEL BIOBÍO           83      BIOBÍO         8313
# 3           16         DE ÑUBLE          162       ITATA        16206
# 4            5    DE VALPARAÍSO           51  VALPARAÍSO         5109
#
#     nom_com_rbd  ...  marcadif_lect4b_rbd marcadif_mate4b_rbd  \
# 0     SAN PABLO  ...                  1.0                 1.0
# ...

# %%
df18 = pd.read_excel(cuarto2018)
df18 = filtrar(df18)
df18.head()
# Out:
#   grado  rbd  dvrbd                                  nom_rbd  cod_reg_rbd  \
# 0    4b    5      1                 JOVINA NARANJO FERNANDEZ           15
# 1    4b    8      6  COLEGIO INTEGRADO EDUARDO FREI MONTALVA           15
# 2    4b    9      4              ESCUELA REPUBLICA DE ISRAEL           15
# 3    4b   10      8             ESCUELA REPUBLICA DE FRANCIA           15
# 4    4b   11      6          ESC. GRAL. PEDRO LAGOS MARCHANT           15
#
#                     nom_reg_rbd  cod_pro_rbd nom_pro_rbd  cod_com_rbd  \
# 0  Región de Arica y Parinacota          151       ARICA        15101
# 1  Región de Arica y Parinacota          151       ARICA        15101
# 2  Región de Arica y Parinacota          151       ARICA        15101
# 3  Región de Arica y Parinacota          151       ARICA        15101
# 4  Región de Arica y Parinacota          151       ARICA        15101
#
#   nom_com_rbd  ...  marcadif_lect4b_rbd marcadif_mate4b_rbd  \
# ...

# %%
df17 = pd.read_excel(cuarto2017)
df17 = filtrar(df17)
df17.head()
# Out:
#   grado    rbd  dvrbd                                       nom_rbd  \
# 0    4b  24403      1                         COLEGIO SIMON BOLIVAR
# 1    4b   2917      3                                 ESCUELA RAUCO
# 2    4b   4506      3                       ESCUELA HÉROES DE CHILE
# 3    4b   5834      3                         ESC. BASICA ALTO MECO
# 4    4b   7423      3  ESCUELA RURAL ALEJANDRO VASQUEZ BALDEVELLANO
#
#    cod_reg_rbd                nom_reg_rbd  cod_pro_rbd nom_pro_rbd  \
# 0           13  METROPOLITANA DE SANTIAGO            1    SANTIAGO
# 1            7                  DEL MAULE            1      CURICÓ
# 2            8                 DEL BIOBÍO            2      BIOBÍO
# 3            9            DE LA ARAUCANÍA            2      CAUTÍN
# 4           10               DE LOS LAGOS            2      OSORNO
#
#    cod_com_rbd nom_com_rbd  ...  marca_lect4b_rbd  marca_mate4b_rbd  \
# 0           17  LA PINTANA  ...               NaN               NaN
# ...
